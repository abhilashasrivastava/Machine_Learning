# %%
import pandas as pd

# %% [markdown]
# # New Section

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
l = ['apple', 'banana', 'mango','orange', 'papaya']
s = pd.Series(l)
s
# Out:
# 0     apple
# 1    banana
# 2     mango
# 3    orange
# 4    papaya
# dtype: object

# %%
s = pd.Series(l, index = [2, 3, 4, 5, 6])
s
# Out:
# 2     apple
# 3    banana
# 4     mango
# 5    orange
# 6    papaya
# dtype: object

# %%
l1 = [['apple', 'fruit'], ['banana', 'fruit'], ['carrot', 'vegetable'], ['onion', 'vegetable'], ['papaya', 'fruit']]
df = pd.DataFrame(l1)
df
# Out:
#         0          1
# 0   apple      fruit
# 1  banana      fruit
# 2  carrot  vegetable
# 3   onion  vegetable
# 4  papaya      fruit

# %%
df = pd.DataFrame(l1, columns = ['food_name', 'food_type'], dtype = 'O')
df
# Out:
#   food_name  food_type
# 0     apple      fruit
# 1    banana      fruit
# 2    carrot  vegetable
# 3     onion  vegetable
# 4    papaya      fruit

# %%
df['food_name'][1]
# Out:
# 'banana'

# %%
df['food_name'][1] = 'null' # wrong practice
df.loc[1, 'food_name'] = 'null' # correct way
df
# Out:
#   food_name  food_type
# 0     apple      fruit
# 1      null      fruit
# 2    carrot  vegetable
# 3     onion  vegetable
# 4    papaya      fruit

# %%
df.loc[1]
# Out:
# food_name     null
# food_type    fruit
# Name: 1, dtype: object

# %%
dd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-06f342d4bc0b> in <cell line: 1>()
# ----> 1 dd
#
# NameError: name 'dd' is not defined

# %%
s.iloc[0: 3]
# Out:
# 2     apple
# 3    banana
# 4     mango
# dtype: object

# %%
df.max(), df.min()
# Out:
# (food_name       papaya
#  food_type    vegetable
#  dtype: object,
#  food_name    apple
#  food_type    fruit
#  dtype: object)

# %%
# read_csv
